# %%
def write_list_tofile(filename, data_list):
        with open(filename, 'w') as file:
           for item in data_list:
               file.write(item + '\n')
    
the_list = ["Hello, world", "Test", "Writing a string"]
file_name = "output.txt"
write_list_tofile(file_name, the_list)

# %% [markdown]
# ![image.png](attachment:image.png)
