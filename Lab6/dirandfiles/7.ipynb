# %%
def copyFile(first_file, second_file):
    with open(first_file, 'r') as first:
        content = first.read()

    with open(second_file, 'w') as sec:
        sec.write(content)
        
f1 = "A.txt"
f2 = "B.txt"

copyFile(f1, f2)
print("Contents of f1 copied to f2")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
