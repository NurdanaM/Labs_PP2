# %%
from time import sleep
import math

def sqrt_func(x):
    return math.sqrt(x)

var = float(input("Enter a number: "))
milliseconds = float(input("Enter milliseconds: "))

sleep(milliseconds / 1000)

res = sqrt_func(var)
print(f"Square root of {var} after {milliseconds} is {res}")

# %% [markdown]
# ![image.png](attachment:image.png)
