# %%
def squares(a, b):
    for i in range(a, b + 1):
        yield i * i

a = int(input("Enter the a: "))
b = int(input("Enter the b: "))

gen = squares(a, b)

for num in gen:
    print(num)

# %% [markdown]
# ![image.png](attachment:image.png)
