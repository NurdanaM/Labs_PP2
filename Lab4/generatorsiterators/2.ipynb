# %%
def even_numbers(n):
    for i in range(0, n + 1):
        if i % 2 == 0 :
            yield i

n = int(input("Enter the num: "))
gen = even_numbers(n)

for num in gen:
    print(num, end=", ")

# %% [markdown]
# ![image.png](attachment:image.png)
