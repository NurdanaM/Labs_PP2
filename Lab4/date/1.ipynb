# %%
from datetime import datetime, timedelta

currentData = datetime.now()

newData = currentData - timedelta(days=5)

print("Current Data: ", currentData.strftime("%d-%m-%Y"))
print("Five days ago: ", newData.strftime("%d-%m-%Y"))

# %% [markdown]
# ![image.png](attachment:image.png)
