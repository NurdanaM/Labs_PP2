# %%
from datetime import datetime, timedelta

d1 = datetime(2025, 2, 9, 13, 0, 0)
d2 = datetime(2025, 2, 8, 16, 30, 0)

diff = d1 - d2

diff_seconds = diff.total_seconds()

print(d1)
print(d2)
print("Difference in seconds: ", diff_seconds)

# %% [markdown]
# ![image.png](attachment:image.png)
