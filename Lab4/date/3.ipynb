# %%
from datetime import datetime

with_microsec = datetime.now()

without_microsec = with_microsec.replace(microsecond=0)

print("With: ", with_microsec)
print("Without: ", without_microsec)

# %% [markdown]
# ![image.png](attachment:image.png)
