# %%
import json

file_path = "/Users/nurdanam/Desktop/all_labs_pp2/Lab4/jsontask/sample-data.json"

with open(file_path, "r") as file:
    data = json.load(file)

print("Interface Status")
print("=" * 80)
print(f"{'DN':<50} {'Description':<20} {'Speed':<7} {'MTU':<5}")
print(f"{'-'* 49:<50} {'-'* 18:<20} {'-'* 6:<7} {'-'* 4:<5}")
for i in data["imdata"][:3]:
    attributes = i["l1PhysIf"]["attributes"]
    dn = attributes["dn"]
    description = attributes["descr"] 
    speed = attributes["speed"]
    mtu = attributes["mtu"]

    print(f"{dn:<50} {description:<20} {speed:<7} {mtu:<5}")

# %% [markdown]
# ![image.png](attachment:image.png)
