# %%
import re
def find_match(text):
    patterns = '^[a-z]+_[a-z]+$'
    if re.search(patterns, text):
        return 'Match found!'
    else:
        return 'Match not found!'

print(find_match("test_world"))
print(find_match("Hello_World"))
print(find_match("case_let_ter"))

# %% [markdown]
# ![image.png](attachment:image.png)
