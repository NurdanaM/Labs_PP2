# %%
import re
def find_match(text):
    patterns = '[A-Z][a-z]+'
    if re.search(patterns, text):
        return 'Match found!'
    else:
        return 'Match not found!'
    
print(find_match("Hello"))
print(find_match("A"))
print(find_match("world"))
print(find_match("Test"))

# %% [markdown]
# ![image.png](attachment:image.png)
