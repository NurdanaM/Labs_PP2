# %%
import re

def snake_to_camel(snake_string):
    return re.sub(r'_([a-z])', lambda m: m.group(1).upper(), snake_string)

print(snake_to_camel("hello_world"))
print(snake_to_camel("Test_string_this"))

# %% [markdown]
# ![image.png](attachment:image.png)
