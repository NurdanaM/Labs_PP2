# %%
import re
def find_match(text):
    patterns = 'ab{2,3}?'
    if re.search(patterns, text):
        return 'Match found!'
    else:
        return 'Match not found!'
    
print(find_match("abb"))
print(find_match("abbb"))
print(find_match("bbaa"))
print(find_match("ab"))

# %% [markdown]
# ![image.png](attachment:image.png)
