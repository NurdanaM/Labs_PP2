# %%
import re

def camel_to_snake(camel_string):
    return re.sub(r'([a-z])([A-Z])', r'\1_\2', camel_string).lower()

print(camel_to_snake("helloWorld"))
print(camel_to_snake("CamelCaseWord"))

# %% [markdown]
# ![image.png](attachment:image.png)
