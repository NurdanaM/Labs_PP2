# %%
import re
def find_match(text):
    patterns = 'a.*?b$'
    if re.search(patterns, text):
        return 'Match found!'
    else:
        return 'Match not found!'
    
print(find_match("asdb"))
print(find_match("abb"))
print(find_match("ba"))
print(find_match("a123b"))

# %% [markdown]
# ![image.png](attachment:image.png)
