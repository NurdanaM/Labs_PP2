# %%
import re
def find_match(text):
    patterns = 'ab*?'
    if re.search(patterns, text):
        return 'Match found!'
    else:
        return 'Match not found!'

print(find_match("a"))
print(find_match("abb"))
print(find_match("ac"))
print(find_match("b"))

# %% [markdown]
# ![image.png](attachment:image.png)
